# %%
#imports
import pandas as pd
import time
from background_functions import logdiffexp, G2G_varying_LL, G2G_varying_MLE, G2G_varying_optim

# %%
#read in the data 
kb = pd.read_csv('~/Downloads/kb_covars.csv')

# %%
last_instance_index = kb.groupby('id').tail(1).index

# Initialize event column
kb['Event'] = 0

# Create the event column
kb.loc[last_instance_index, 'Event'] = kb.loc[last_instance_index, 'censor'].apply(lambda x: 1 if x == 0 else 0)

kb2  = kb.copy()

# print df
kb.head(10)
# Out:
#    id  week  num_weeks  censor  coupon   anyp  Event
# 0   1     1          1       0     0.0  55.61      1
# 1   2     1          1       0     0.0  55.61      1
# 2   3     1          1       0     0.0  55.61      1
# 3   4     1          1       0     0.0  55.61      1
# 4   5     1          1       0     0.0  55.61      1
# 5   6     1          1       0     0.0  55.61      1
# 6   7     1          1       0     0.0  55.61      1
# 7   8     1          1       0     0.0  55.61      1
# 8   9     1          2       0     0.0  55.61      0
# 9   9     2          2       0     0.0  55.82      1

# %%
#data manipulation steps
# Data manipulation
id_df = kb.groupby('id')['censor'].max().reset_index()

kb2 = kb2.drop(columns=['censor']).merge(id_df, on='id', how='inner')

kb2['status'] = (kb2['censor'] + 1) % 2

display(kb2.head(50))
print(kb2['status'].min())
# Out:
#     id  week  num_weeks    coupon   anyp  Event  time  censor  status
# 0    1     1          1  0.000000  55.61      1     1       0       1
# 1    2     1          1  0.000000  55.61      1     1       0       1
# 2    3     1          1  0.000000  55.61      1     1       0       1
# 3    4     1          1  0.000000  55.61      1     1       0       1
# 4    5     1          1  0.000000  55.61      1     1       0       1
# 5    6     1          1  0.000000  55.61      1     1       0       1
# 6    7     1          1  0.000000  55.61      1     1       0       1
# 7    8     1          1  0.000000  55.61      1     1       0       1
# 8    9     1          2  0.000000  55.61      0     1       0       1
# 9    9     2          2  0.000000  55.82      1     2       0       1
# 10  10     1          2  0.000000  55.61      0     1       0       1
# 11  10     2          2  0.000000  55.82      1     2       0       1
# 12  11     1          2  0.000000  55.61      0     1       0       1
# 13  11     2          2  0.000000  55.82      1     2       0       1
# 14  12     1          2  0.000000  55.61      0     1       0       1
# 15  12     2          2  0.000000  55.82      1     2       0       1
# 16  13     1          2  0.000000  55.61      0     1       0       1
# 17  13     2          2  0.000000  55.82      1     2       0       1
# 18  14     1          2  0.000000  55.61      0     1       0       1
# 19  14     2          2  0.000000  55.82      1     2       0       1
# 20  15     1          3  0.000000  55.61      0     1       0       1
# 21  15     2          3  0.000000  55.82      0     2       0       1
# 22  15     3          3  0.018037  55.65      1     3       0       1
# 23  16     1          3  0.000000  55.61      0     1       0       1
# 24  16     2          3  0.000000  55.82      0     2       0       1
# 25  16     3          3  0.018037  55.65      1     3       0       1
# 26  17     1          4  0.000000  55.61      0     1       0       1
# 27  17     2          4  0.000000  55.82      0     2       0       1
# 28  17     3          4  0.018037  55.65      0     3       0       1
# 29  17     4          4  0.126259  81.17      1     4       0       1
# 30  18     1          4  0.000000  55.61      0     1       0       1
# 31  18     2          4  0.000000  55.82      0     2       0       1
# 32  18     3          4  0.018037  55.65      0     3       0       1
# 33  18     4          4  0.126259  81.17      1     4       0       1
# 34  19     1          4  0.000000  55.61      0     1       0       1
# 35  19     2          4  0.000000  55.82      0     2       0       1
# 36  19     3          4  0.018037  55.65      0     3       0       1
# 37  19     4          4  0.126259  81.17      1     4       0       1
# 38  20     1          4  0.000000  55.61      0     1       0       1
# 39  20     2          4  0.000000  55.82      0     2       0       1
# 40  20     3          4  0.018037  55.65      0     3       0       1
# 41  20     4          4  0.126259  81.17      1     4       0       1
# 42  21     1          4  0.000000  55.61      0     1       0       1
# 43  21     2          4  0.000000  55.82      0     2       0       1
# 44  21     3          4  0.018037  55.65      0     3       0       1
# 45  21     4          4  0.126259  81.17      1     4       0       1
# 46  22     1          4  0.000000  55.61      0     1       0       1
# 47  22     2          4  0.000000  55.82      0     2       0       1
# 48  22     3          4  0.018037  55.65      0     3       0       1
# 49  22     4          4  0.126259  81.17      1     4       0       1
# 0

# %%
kb2['time'] = kb2['week']
start_time = time.time()
test_sol= G2G_varying_MLE(time = 'week', status = 'status',  data=kb2, subject="id") 
elapsed_time = time.time() - start_time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 kb2['time'] = kb2['week']
#       2 start_time = time.time()
# ----> 3 test_sol= G2G_varying_MLE(time = 'week', status = 'status',  data=kb2, subject="id")
#       4 elapsed_time = time.time() - start_time
#
# File ~/background_functions.py:82, in G2G_varying_MLE(time, status, data, subject)
#      73 X = pd.get_dummies(df_temp, drop_first=True)
#      75 model_data = pd.DataFrame({
#      76     'id': data[subject].values.flatten(),
#      77     'time': data[time_name].values.flatten(),
#      78     'status': data[status_name].values.flatten(),
#      79     'X': X.values.tolist()
#      80 })
# ---> 82 return G2G_varying_optim(model_data)
#
# File ~/background_functions.py:121, in G2G_varying_optim(model_data)
#     118 upper_bounds = [np.inf, np.inf] + [5.0] * (nvar - 2)
#     120 # Perform optimization
# --> 121 solution = minimize(objective_function, x0=par, method='L-BFGS-B',
#     122                     bounds=list(zip(lower_bounds, upper_bounds)), options={'maxiter': 1000})
#     124 # Compute standard errors
#     125 par_stderr = np.sqrt(np.diag(np.linalg.inv(solution.hess_inv)))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_minimize.py:713, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
# --> 713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:309, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     306         iprint = disp
#     308 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 309 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     310                               bounds=bounds,
#     311                               finite_diff_rel_step=finite_diff_rel_step)
#     313 func_and_grad = sf.fun_and_grad
#     315 fortran_int = _lbfgsb.types.intvar.dtype
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:402, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     398     bounds = (-np.inf, np.inf)
#     400 # ScalarFunction caches. Reuse of fun(x) during grad
#     401 # calculation reduces overall function evaluations.
# --> 402 sf = ScalarFunction(fun, x0, args, grad, hess,
#     403                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     405 return sf
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File ~/background_functions.py:111, in G2G_varying_optim.<locals>.objective_function(par)
#     110 def objective_function(par):
# --> 111     return G2G_varying_LL(par, model_data)
#
# File ~/background_functions.py:29, in G2G_varying_LL(par, data_df)
#      25 coeff = par[2:]
#      27 X = data_df.iloc[:, 3:].values
# ---> 29 data_df['Ct'] = np.exp(np.dot(X, coeff))
#      31 data_df['cumsumCt'] = data_df.groupby('id')['Ct'].cumsum()
#      32 # gather unique id information
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
import numpy as np
kb2['time'] = kb2['week']
nvar = kb2.shape[1] - 1
lower_bounds = [0.001, 0.001] + [-5.0] * (nvar - 2)
initial_par = np.concatenate(([0.5, 0.05], np.zeros(nvar - 2)))

# %%
nvar = kb2.shape[1] - 1
par = np.concatenate(([0.5, 0.05], np.zeros(nvar - 2)))

# %%
import numpy as np
coeff = par[2:]
X = kb2.iloc[:, 3:].values
np.exp(np.dot(X, coeff))
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])
